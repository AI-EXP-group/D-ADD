# %%
import torch

old = torch.load("mean&cov/cifar10/mean_class.pt")
new = torch.load("mean&cov/cifar10/wrn16_4_mean_class.pt")
print(old)
print(new)
# Out:
# tensor([[5.2387e-02, 2.2912e-01, 3.2773e-02,  ..., 5.3032e-05, 3.2675e-01,
#          3.3868e-01],
#         [4.9472e-01, 1.5098e-01, 2.1810e-02,  ..., 3.4832e-05, 1.7809e-01,
#          1.7765e-01],
#         [1.0058e-01, 1.0018e-01, 6.7813e-02,  ..., 5.4457e-05, 1.9181e-01,
#          1.6287e-01],
#         ...,
#         [6.6592e-02, 1.5790e+00, 3.4959e-02,  ..., 5.3041e-05, 1.2473e+00,
#          1.4924e+00],
#         [9.9152e-02, 1.1208e-01, 2.2488e-02,  ..., 5.8990e-05, 1.3801e+00,
#          1.1017e-01],
#         [9.0864e-02, 1.2351e-01, 2.0178e-02,  ..., 3.7942e-05, 2.3808e-01,
#          1.7159e-01]])
# tensor([[0.1007, 0.7607, 0.1757,  ..., 0.0785, 0.1723, 0.2548],
#         [0.0425, 0.1344, 0.1924,  ..., 0.0843, 0.0674, 0.1611],
#         [0.0537, 0.1078, 0.1859,  ..., 0.5785, 0.5481, 1.1711],
#         ...,
#         [0.0958, 0.2633, 0.2386,  ..., 0.1173, 0.0885, 0.2288],
#         [0.2516, 0.7007, 0.2034,  ..., 0.2457, 0.0576, 0.1103],
# ...

# %%
import numpy as np


cifar10 = np.load('distance/wrn16_4_cifar100/cifar10_256.npy')
cifar100 = np.load('distance/wrn16_4_cifar100/cifar100_256.npy')
print(cifar10)
print(cifar100)
count = np.sum((cifar10 >= np.min(cifar10)) & (cifar10 <= np.max(cifar100)))
print(count)
count = np.sum((cifar100 >= np.min(cifar10)) & (cifar100 <= np.max(cifar100)))
print(count)
# Out:
# [88.49821  81.11852  82.15802  87.303055 85.80501  88.050224 87.31594
#  83.09943  85.64846  85.71525  84.67585  85.808365 83.52277  88.43944
#  82.150505 83.23164  86.87944  86.561264 85.787094 83.96079  89.64059
#  86.873726 85.84302  85.339424 85.828476 82.696846 87.09028  83.59798
#  81.87255  84.724625 89.40442  81.48584  84.1292   82.902405 86.45691
#  87.151215 87.54097  86.356636 83.26042 ]
# [83.40601  80.795555 83.96715  80.99582  81.52375  81.791046 82.655495
#  82.6904   81.57589  82.02086  80.39661  79.33632  83.37359  83.07491
#  82.24641  82.44399  85.05789  81.25459  84.11983  80.46314  82.711784
#  81.51661  84.063286 81.77322  80.92856  81.74592  85.45376  83.60642
#  84.76002  84.775215 84.35661  81.88794  82.95303  82.48779  83.58799
#  83.93033  83.94704  83.74741  83.66586 ]
# 17
# 33
